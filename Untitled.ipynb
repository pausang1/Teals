# %% [markdown]
# # Intro to Python
# - [input and Output](#Input-and-Output)
# - [Python Variables](#Python-Variables)
# - [Arithmetic and Boolen Operators](#Arithmetic-and-Boolean-Operators)

# %% [markdown]
# ## Input and Output

# %%
input()
# Out:
#  Hi there

# %%
input()
# Out:
#  Hi there
# 'Hi there'

# %%
input("Please type your name")
# Out:
# Please type your name Sang
# 'Sang'

# %%
print("My name is Sang")
# Out:
# My name is Sang

# %%
print("AAA" "BBB" "CCC")
# Out:
# AAABBBCCC

# %%
print("AAA", "BBB", "CCC")
# Out:
# AAA BBB CCC

# %%
print("ABCD")
# Out:
# ABCD

# %% [markdown]
# # Python Variables

# %%
Me="About me"
Sport="soccer"
School="Towers High School"
age=18
name="Sang"

# %%
print(Me)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_116/2026545213.py in <module>
# ----> 1 print(Me)
#
# NameError: name 'Me' is not defined

# %%
print(name)
# Out:
# Sang

# %%
print(Me)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_116/2026545213.py in <module>
# ----> 1 print(Me)
#
# NameError: name 'Me' is not defined

# %%
print(Me)
# Out:
# About me

# %%
print("My name is" name,  )
# Out:
#   File "/tmp/ipykernel_116/316575532.py", line 1
#     print("My name is" name,  )
#                           ^
# SyntaxError: invalid syntax

# %%
print("My name is",print(name)  )
# Out:
# Sang
# My name is None

# %%
print("My name is (name)")
# Out:
# My name is (name)

# %%
print(Name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_116/2644917711.py in <module>
# ----> 1 print(Name)
#
# NameError: name 'Name' is not defined

# %%
name=input(Type your name:)
# Out:
#   File "/tmp/ipykernel_116/1753936485.py", line 1
#     name=input(Type your name:)
#                        ^
# SyntaxError: invalid syntax

# %%
Name=input("Type your name")
# Out:
# Type your name Sang

# %%
print(Name)
# Out:
# Sang

# %% [markdown]
# ## Arithmetic and Boolean Operators

# %%
5+7
# Out:
# 12

# %%
80-23
# Out:
# 57

# %%
324*21
# Out:
# 6804

# %%
20/21
# Out:
# 0.9523809523809523

# %%
22/2
# Out:
# 11.0

# %%
70%3
# Out:
# 1

# %%
23+32(23-213)/12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_116/3032027803.py in <module>
# ----> 1 23+32(23-213)/12
#
# TypeError: 'int' object is not callable

# %%
7+24/3+2
# Out:
# 17.0

# %%
area = 3242

# %%
area+21
# Out:
# 3263

# %%
print(10>5)
# Out:
# True

# %%
print(342>3242342)
# Out:
# False
